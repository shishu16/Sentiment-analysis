# %%
pip install tweepy
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: tweepy in c:\users\shikhar\appdata\roaming\python\python39\site-packages (4.10.1)
# Requirement already satisfied: requests<3,>=2.27.0 in c:\programdata\anaconda3\lib\site-packages (from tweepy) (2.27.1)
# Requirement already satisfied: oauthlib<4,>=3.2.0 in c:\users\shikhar\appdata\roaming\python\python39\site-packages (from tweepy) (3.2.1)
# Requirement already satisfied: requests-oauthlib<2,>=1.2.0 in c:\users\shikhar\appdata\roaming\python\python39\site-packages (from tweepy) (1.3.1)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\programdata\anaconda3\lib\site-packages (from requests<3,>=2.27.0->tweepy) (1.26.9)
# Requirement already satisfied: idna<4,>=2.5 in c:\programdata\anaconda3\lib\site-packages (from requests<3,>=2.27.0->tweepy) (3.3)
# Requirement already satisfied: certifi>=2017.4.17 in c:\programdata\anaconda3\lib\site-packages (from requests<3,>=2.27.0->tweepy) (2021.10.8)
# Requirement already satisfied: charset-normalizer~=2.0.0 in c:\programdata\anaconda3\lib\site-packages (from requests<3,>=2.27.0->tweepy) (2.0.4)
# Note: you may need to restart the kernel to use updated packages.

# %%
import tweepy
import matplotlib.pyplot as plt
from  textblob import TextBlob 
import time

# %%
# all 4 authentication keys to access twitter API
# to connect as OAth handler or jump serever / revers proxy server
consumer_key = "your_consumer_key"
consumer_sec = "your_consumer_sec"


# from proxy server we need to connect
access_token = "your_access_token"
access_token_sec = "your_access_token_sec"

# %%
# connected to jump server of twitter
auth=tweepy.OAuthHandler(consumer_key,consumer_sec)

# %%
# now we can connect from jump server to web server of twitter
auth.set_access_token(access_token,access_token_sec)

# %%
# now we can connect to API storge server of twitter
api_connect=tweepy.API(auth)

# %%
# now you can search any topic on twitter
tweet_data=api_connect.search_tweets('Delhi',count=100)

# %%
# tweepy explore
dir(api_connect)
# Out:
# ['__class__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  'add_list_member',
#  'add_list_members',
#  'auth',
#  'available_trends',
#  'cache',
#  'cached_result',
#  'chunked_upload',
#  'chunked_upload_append',
#  'chunked_upload_finalize',
#  'chunked_upload_init',
#  'closest_trends',
#  'create_block',
#  'create_favorite',
#  'create_friendship',
#  'create_list',
#  'create_media_metadata',
#  'create_mute',
#  'create_saved_search',
#  'delete_direct_message',
#  'destroy_block',
#  'destroy_favorite',
#  'destroy_friendship',
#  'destroy_list',
#  'destroy_mute',
#  'destroy_saved_search',
#  'destroy_status',
#  'geo_id',
#  'get_blocked_ids',
#  'get_blocks',
#  'get_direct_message',
#  'get_direct_messages',
#  'get_favorites',
#  'get_follower_ids',
#  'get_followers',
#  'get_friend_ids',
#  'get_friends',
#  'get_friendship',
#  'get_list',
#  'get_list_member',
#  'get_list_members',
#  'get_list_memberships',
#  'get_list_ownerships',
#  'get_list_subscriber',
#  'get_list_subscribers',
#  'get_list_subscriptions',
#  'get_lists',
#  'get_media_upload_status',
#  'get_muted_ids',
#  'get_mutes',
#  'get_oembed',
#  'get_place_trends',
#  'get_profile_banner',
#  'get_retweeter_ids',
#  'get_retweets',
#  'get_retweets_of_me',
#  'get_saved_search',
#  'get_saved_searches',
#  'get_settings',
#  'get_status',
#  'get_user',
#  'home_timeline',
#  'host',
#  'incoming_friendships',
#  'indicate_direct_message_typing',
#  'last_response',
#  'list_timeline',
#  'lookup_friendships',
#  'lookup_statuses',
#  'lookup_users',
#  'mark_direct_message_read',
#  'media_upload',
#  'mentions_timeline',
#  'no_retweets_friendships',
#  'outgoing_friendships',
#  'parser',
#  'proxy',
#  'rate_limit_status',
#  'remove_list_member',
#  'remove_list_members',
#  'remove_profile_banner',
#  'report_spam',
#  'request',
#  'retry_count',
#  'retry_delay',
#  'retry_errors',
#  'retweet',
#  'reverse_geocode',
#  'search_30_day',
#  'search_full_archive',
#  'search_geo',
#  'search_tweets',
#  'search_users',
#  'send_direct_message',
#  'session',
#  'set_settings',
#  'simple_upload',
#  'subscribe_list',
#  'supported_languages',
#  'timeout',
#  'unretweet',
#  'unsubscribe_list',
#  'update_friendship',
#  'update_list',
#  'update_profile',
#  'update_profile_banner',
#  'update_profile_image',
#  'update_status',
#  'update_status_with_media',
#  'upload_host',
#  'user_agent',
#  'user_timeline',
#  'verify_credentials',
#  'wait_on_rate_limit']

# %%
pos=0
neg=0
neu=0

# printing line by line
for tweet in tweet_data:
   print(tweet.text)
   analysis=TextBlob(tweet.text) # here it will apply NLP\
   print(analysis.sentiment)
   # now checking polarity only
   if analysis.sentiment.polarity > 0:
      print("positive")
      pos=pos+1
   elif analysis.sentiment.polarity == 0 :
      print("Neutral")
      neu=neu+1
   else :
      print("Negative")
      neg=neg+1
# Out:
# RT @zoo_bear: "दिल्ली ही नहीं पूरे देश को झकझोर देने वाली इस घटना में जो 5 आरोपी हैं, उनमें एक बीजेपी नेता है। बताया जा रहा है कि इस कांड…
# Sentiment(polarity=0.0, subjectivity=0.0)
# Neutral
# RT @gchahal: BREAKING: #BNNIndia Reports.
#
# Delhi witnessed the launching of 50 new low-floor electric buses.
#
# Arvind Kejriwal said by the…
# Sentiment(polarity=0.13636363636363635, subjectivity=0.45454545454545453)
# positive
# #TheUrbanDebate | WOMAN DRAGGED TO DEATH IN #DELHI
# #DelhiPolice Display No Alert On Murder
#
# "It's extremely unnatur… https://t.co/zwKXB6Nnvu
# Sentiment(polarity=-0.125, subjectivity=1.0)
# Negative
# RT @epanchjanya: दिल्ली कार कांड : मेरा सिर शर्म से झुक गया, मैं अपराधियों की राक्षसी संवेदनहीनता से स्तब्ध हूं – LG
#
# एलजी ने कहा कि उन्हों…
# Sentiment(polarity=0.0, subjectivity=0.0)
# Neutral
# RT @MahuaMoitra: Horrific incident in Delhi with lady being dragged for 12kms or more. Traffic guards  at nightposts necessity for our capi…
# Sentiment(polarity=-0.25, subjectivity=0.75)
# Negative
# RT @AlstomIndia: Ready to rock and roll!
# Here are @Alstom's first semi-high speed trainsets in #India ready to blitz the tracks on the 17-k…
# Sentiment(polarity=0.2333333333333333, subjectivity=0.4444444444444444)
# positive
# THOUGHT OF THE DAY - Y01 – D015
#
# #Positivity #PositivityEnsuredToday #PositivityEnsured #tvssl #SumatiEducation… https://t.co/Jb3Yj0QbNX
# Sentiment(polarity=0.0, subjectivity=0.0)
# Neutral
# RT @SouleFacts: On the directions of HM @AmitShah ji,an official said MHA seeks report from
# Delhi Police on Delhi hit-and-run case where a…
# Sentiment(polarity=0.0, subjectivity=0.0)
# Neutral
# RT @ashoswai: On the New Year eve, a 20-year-old girl in India’s capital Delhi, was killed after she was hit by a car and then dragged for…
# Sentiment(polarity=-0.03181818181818183, subjectivity=0.22727272727272727)
# Negative
# @zoo_bear The issue of illegality comes into picture only when it happens to be Muslims. Last year, Modi boasted of… https://t.co/nTanVRhuJs
# Sentiment(polarity=0.0, subjectivity=0.5333333333333333)
# Neutral
# RT @krishan11554791: दिल्ली की बेटी की हत्या के आरोपी BJP नेता को बचाने में लगे हैं LG और Delhi Police
#
# #ShameOnLGSaxena https://t.co/gugrK…
# Sentiment(polarity=0.0, subjectivity=0.0)
# Neutral
# RT @SACHKAHOON: मौसम विभाग की शीतलहर को लेकर चेतावनी https://t.co/B6CKKtJ1r6
# Sentiment(polarity=0.0, subjectivity=0.0)
# Neutral
# RT @CMO_Odisha: On behalf of Hon'ble CM Shri @Naveen_Odisha, #Odisha Minister Shri @NiranjanPujar11 met #Delhi CM Shri @ArvindKejriwal and…
# Sentiment(polarity=0.0, subjectivity=0.0)
# Neutral
# RT @Tweet2Chayan: aisa sirf AAP ki imaandar sarkaar mein hi ho sakta hai. Saal bhar ka revenue projection Delhi govt. ne sir 3 quarter mein…
# Sentiment(polarity=0.0, subjectivity=0.0)
# Neutral
# RT @Raajeev_Chopra: On Home Minister Amit Shah's direction, MHA seeks report from Delhi Police on gruesome death of woman after being dragg…
# Sentiment(polarity=-1.0, subjectivity=1.0)
# Negative
# RT @AAPDelhi: दिल्ली के अंदर एक बेटी को सड़क पर रौंद कर मार दिया गया।
#
# LG साहब के Under Delhi Police मामले को दबाने में लगी हुई है।
#
# हम सवा…
# Sentiment(polarity=0.0, subjectivity=0.0)
# Neutral
# BJP नेता मनोज मित्तल व अन्य 4 के द्वारा 31 Dec की रात जो घिनौना कृत्य किया गया, उस पर पुलिस सख्त कार्यवाही करने की… https://t.co/BSOqQLgVS1
# Sentiment(polarity=0.0, subjectivity=0.0)
# Neutral
# RT @Bhargavkuldeep7: दिल्ली की एक मासूम बेटी को सड़क पर घसीट-घसीट कर मारने वाला BJP का नेता है।
#
# इस वजह से मामले पर LG और Delhi Police लीपा…
# Sentiment(polarity=0.0, subjectivity=0.0)
# Neutral
# Urmi Group is one of the leading house cleaning service providers in Delhi NCR.
#
# 📞+91 97170 59515
# 🪩… https://t.co/HQ6q7B2Mm7
# Sentiment(polarity=0.0, subjectivity=0.0)
# Neutral
# RT @NavodayaParty: सत्ता को पाने तथा सत्ता में बने रहने की भूख के साथ,पार्टी में बिना चरित्र प्रमाणन के किसी को भी शामिल करने का हश्र यही…
# Sentiment(polarity=0.0, subjectivity=0.0)
# Neutral
# RT @hello_nicks: How can male delhi police officer slap a woman like this ? I know police won't take any action against his own person desp…
# Sentiment(polarity=0.2333333333333333, subjectivity=0.39999999999999997)
# positive
# RT @ndtv: 🔴 #BREAKING | Amit Shah asks top cop to probe case of woman dragged under car in Delhi, asks for report https://t.co/YVARufGcwC h…
# Sentiment(polarity=0.5, subjectivity=0.5)
# positive
# RT @aajtak: आम आदमी पार्टी ने दिल्ली की लचर कानून व्यवस्था के खिलाफ एलजी हाउस का घेराव किया
# #Delhi| @PankajJainClick
# https://t.co/vPozawZX…
# Sentiment(polarity=0.0, subjectivity=0.0)
# Neutral
# RT @TNStateAviation: Privatisation is not a solution. Delhi and Bombay too are witnessing the same problem. The actual problem is inability…
# Sentiment(polarity=0.0, subjectivity=0.1125)
# Neutral
# RT @AamAadmiParty: दिल्ली की एक मासूम बेटी को सड़क पर घसीट-घसीट कर मारने वाला BJP का नेता है।
#
# इस वजह से मामले पर LG और Delhi Police लीपापो…
# Sentiment(polarity=0.0, subjectivity=0.0)
# Neutral
# RT @SanjayAzadSln: LG विनय सक्सेना अपराधियों को बचाने का पुरजोर प्रयास कर रहे सिर्फ इसलिए कि वो भाजपा नेता हैं।
# LG साहब शर्म करो लड़की के…
# Sentiment(polarity=0.0, subjectivity=0.0)
# Neutral
# RT @ndtv: 🔴 #BREAKING | Men who ran over Delhi woman, dragged body for 13 km, had borrowed car on New Year's eve, tried to flee after crash…
# Sentiment(polarity=0.13636363636363635, subjectivity=0.45454545454545453)
# positive
# RT @krishna_favkid: Whatt.. @MCStanOfficial is going to fo live show in biggboss mene kya bure karma kie hai jo delhi me nahi krraha shows…
# Sentiment(polarity=0.13636363636363635, subjectivity=0.5)
# positive
# RT @ashoswai: Modi had promised to build homes for every Indian by 2022. Forget India; even in the capital Delhi, a large number of people…
# Sentiment(polarity=0.21428571428571427, subjectivity=0.42857142857142855)
# positive
# @sherlock__123 Delhi police gaann bajao hum aapke sath hai 😂
# Sentiment(polarity=0.0, subjectivity=0.0)
# Neutral
# RT @DebashishHiTs: A woman in Delhi's Kanjhawala lost her life after being hit by a car in the wee hours of Sunday, 1 January. Her body was…
# Sentiment(polarity=0.0, subjectivity=0.0)
# Neutral
# @avinashahid Even the Dog Noticed it #Delhiaccident #Delhi
# Sentiment(polarity=0.0, subjectivity=0.0)
# Neutral
# RT @RCfanSANATH: Delhi lo #KushiReRelease Celebrations
# Reach vasthe thread vestha https://t.co/MnogtPlsn8
# Sentiment(polarity=0.0, subjectivity=0.0)
# Neutral
# RT @Shivani_Kash: Join world's No 1 Space.
#
# रीट्वीट करें
# रीट्वीट लिस्ट खोलकर सभी को फोलो करें
# सभी को फॉलोबैक करें
#
# Hombale Films
# Heaven On…
# Sentiment(polarity=0.0, subjectivity=0.0)
# Neutral
# @nistula And in Delhi #girl dragged 14 km under his Shoulder (Boss of Delhi Police) but who have courage to ask questions like #Nirbhaya
# Sentiment(polarity=0.0, subjectivity=0.0)
# Neutral
# RT @epanchjanya: दिल्ली कार कांड : मेरा सिर शर्म से झुक गया, मैं अपराधियों की राक्षसी संवेदनहीनता से स्तब्ध हूं – LG
#
# एलजी ने कहा कि उन्हों…
# Sentiment(polarity=0.0, subjectivity=0.0)
# Neutral
# @KapilMishra_IND @AmitShah Sir rahne dijiye lipapoti. Delhi pol is not worth
# Sentiment(polarity=-0.15, subjectivity=0.1)
# Negative
# RT @ani_digital: Amit Shah seeks detailed report from Delhi Police on Kanjhawla incident, Special Commissioner Shalini Singh given task
#
# Re…
# Sentiment(polarity=0.37857142857142856, subjectivity=0.6607142857142857)
# positive
# RT @shambhav15: 1 day of Diwali screws up Delhi air for 300+ days. Environmental Hindutva extr3mism https://t.co/SW87UgFk9Y
# Sentiment(polarity=0.0, subjectivity=0.0)
# Neutral
# RT @PankajJainClick: Delhi Horror: 5 आरोपियों में एक BJP नेता, जानिए कौन है ये
# https://t.co/DYPbwWmZut
# Sentiment(polarity=0.0, subjectivity=0.0)
# Neutral
# RT @editorvskbharat: Supreme Court upholds Centre's 2016 decision to demonetise currency notes of 1000 &amp; 500 Rs. denominations
#
# New Delhi.…
# Sentiment(polarity=0.13636363636363635, subjectivity=0.45454545454545453)
# positive
# RT @MrSinha_: Check the thread, he’s clearly inciting his fellow intruders for violence. Just like Umar Khalid etc did in Delhi.
#
# Uttrakhan…
# Sentiment(polarity=0.10000000000000002, subjectivity=0.3833333333333333)
# positive
# RT @Profdilipmandal: 50% से ज्यादा आरक्षण: बीजेपी के राष्ट्रीय नेतृत्व को ये फैसला करना होगा कि SC, ST, OBC आरक्षण की सीमा 50 प्रतिशत से…
# Sentiment(polarity=0.0, subjectivity=0.0)
# Neutral
# RT @DainikBhaskar: कार सवार लड़कों ने लड़की को 4 KM तक घसीटा: दिल्ली में सड़क पर लहूलुहान पड़ी रही लाश; घिसटने से कपड़े तक फट चुके थे
# https…
# Sentiment(polarity=0.0, subjectivity=0.0)
# Neutral
# RT @IndiaToday: The new year hit and run shocks India. Eyewitness Deepak shares shocking details
# Full show: https://t.co/gUwh3UGbn6
# #ITHigh…
# Sentiment(polarity=-0.17121212121212123, subjectivity=0.6681818181818183)
# Negative
# 13 May, 1962: Dr Rajendra Prasad left New Delhi by a special train for Sadaqat Ashram, Patna, at the end of his ter… https://t.co/CbZ9NE5Aag
# Sentiment(polarity=0.1645021645021645, subjectivity=0.341991341991342)
# positive
# RT @editorvskbharat: Indian Govt asks Pakistan to release 633 Indians languishing in Pakistani jails
#
# New Delhi
# India has asked Pakistan to…
# Sentiment(polarity=0.13636363636363635, subjectivity=0.45454545454545453)
# positive
# RT @SHIFUJIJAIHIND: क्या आप आज भी चुप रहेंगे? Delhi Kanjhawala Girl Murder Case?
# Sultanpuri Delhi News.
#
# #Sultanpuri #Delhi #Kanjhawala #K…
# Sentiment(polarity=0.0, subjectivity=0.0)
# Neutral
# RT @yogitabhayana: "Every single authority has failed this daughter...," Activist Yogita Bhayana on Delhi horror
# #TTP #Sultanpuri #Delhi |…
# Sentiment(polarity=-0.2857142857142857, subjectivity=0.2571428571428571)
# Negative
# RT @zoo_bear: "दिल्ली ही नहीं पूरे देश को झकझोर देने वाली इस घटना में जो 5 आरोपी हैं, उनमें एक बीजेपी नेता है। बताया जा रहा है कि इस कांड…
# Sentiment(polarity=0.0, subjectivity=0.0)
# Neutral
# RT @rana_indrjeet: Mid-19th century Pahari painting of Amarnath, Kashmir.
#
# National museum, Delhi.
#
# #worldwidehindutemples
# #Kashmir #maha…
# Sentiment(polarity=0.0, subjectivity=0.0)
# Neutral
# RT @DaaruBaazMehta: HUGE PROTEST BY AAP AGAINST DELHI LG
#
# Delhi LG has failed to ensure Law &amp; Order in Delhi
#
# AAP MLAs reach LG residence t…
# Sentiment(polarity=-0.04999999999999996, subjectivity=0.6)
# Negative
# RT @barkhatrehan16: Home Ministry orders detailed enquiry by a senior IPS officer Shalini singh.
# #Delhi Kanjhawala Case https://t.co/HU6qKK…
# Sentiment(polarity=0.4, subjectivity=0.75)
# positive
# RT @kushal_jasani: Unemployment Rate (December 2022)
#
# Delhi:20.8%
# Gujarat:2.3%
#
# Source:CMIE https://t.co/0pTUz54CCr
# Sentiment(polarity=0.0, subjectivity=0.0)
# Neutral
# RT @news24tvchannel: "सुल्तानपुरी घटना के आरोपी के वहां होर्डिंग लगे हुए हैं, वो उस इलाके में BJP का अध्यक्ष है"
#
# ◆  AAP के नेता @Saurabh_M…
# Sentiment(polarity=0.0, subjectivity=0.0)
# Neutral
# RT @saket71: Do you also realise that the level of political discourse has become less angry and more sensible since #ArvindKejriwal is in…
# Sentiment(polarity=-0.04166666666666666, subjectivity=0.4166666666666667)
# Negative
# RT @DainikBhaskar: कार सवार लड़कों ने लड़की को 4 KM तक घसीटा: दिल्ली में सड़क पर लहूलुहान पड़ी रही लाश; घिसटने से कपड़े तक फट चुके थे
# https…
# Sentiment(polarity=0.0, subjectivity=0.0)
# Neutral
# RT @AamAadmiParty: #Kanjhawala के दरिंदों का BJP Connection!
#
# आरोपी Manoj Mittal भाजपा का नेता है। जिस जेल में वो बंद है, उसी Jail के बाहर…
# Sentiment(polarity=-0.1, subjectivity=0.0)
# Negative
# https://t.co/BXqLgUweJr
# Sentiment(polarity=0.0, subjectivity=0.0)
# Neutral
# RT @sanjaykore261: दिल्ली के अंदर एक बेटी को सड़क पर रौंद कर मार दिया गया।
#
# LG साहब के Under Delhi Police मामले को दबाने में लगी हुई है।
#
# ह…
# Sentiment(polarity=0.0, subjectivity=0.0)
# Neutral
# RT @AamAadmiParty: दिल्ली की बेटी की हत्या के आरोपी BJP नेता को बचाने में लगे हैं LG और Delhi Police
#
# #ShameOnLGSaxena https://t.co/i7oKWOn…
# Sentiment(polarity=0.0, subjectivity=0.0)
# Neutral
# RT @ShraddaSriram: It took #Anupamaa longer to reach the dance competition than the time Vannu took to reach Ahemdabad from Delhi...
#
# (Joke…
# Sentiment(polarity=0.0, subjectivity=0.0)
# Neutral
# RT @DeshGujarat: Railway Minister Ashwini Vaishnaw during his visit to Pramukh Swami Shatabdi Mahotsav at Ognaj in Gujarat today announced…
# Sentiment(polarity=0.0, subjectivity=0.0)
# Neutral
# RT @zoo_bear: "दिल्ली ही नहीं पूरे देश को झकझोर देने वाली इस घटना में जो 5 आरोपी हैं, उनमें एक बीजेपी नेता है। बताया जा रहा है कि इस कांड…
# Sentiment(polarity=0.0, subjectivity=0.0)
# Neutral
# दिल्ली एयरपोर्ट पहुंचे स्वास्थ्य मंत्री मंडाविया, कोरोना स्थिति का लिया जायजा
#
# #Prachand #BreakingNews #News… https://t.co/GSOZdgbYn3
# Sentiment(polarity=0.0, subjectivity=0.0)
# Neutral
# @aajtak @arvindojha CP police should be removed along with SHO and DSP / SP for derliction of duty. Shame on Delhi police
# Sentiment(polarity=0.0, subjectivity=0.0)
# Neutral
# RT @AamAadmiParty: दिल्ली की बेटी की हत्या के आरोपी BJP नेता को बचाने में लगे हैं LG और Delhi Police
#
# #ShameOnLGSaxena https://t.co/i7oKWOn…
# Sentiment(polarity=0.0, subjectivity=0.0)
# Neutral
# RT @IndiaToday: Delhi horror: Is this not an absolute case of murder? Former IPS Yashovardhan Azad responds
# Full show: https://t.co/2cH7iTT…
# Sentiment(polarity=0.18333333333333335, subjectivity=0.4833333333333334)
# positive
# RT @deepikadeshwal: My father got award and appreciation by Honourable Commissioner of Delhi Police Mr Sanjay Arora sir for his meritorious…
# Sentiment(polarity=0.0, subjectivity=0.0)
# Neutral
# RT @htTweets: The post-mortem of the deceased in the Kanjhawala death case in Delhi was completed, informed Delhi Police
#
# https://t.co/6XU…
# Sentiment(polarity=0.0, subjectivity=0.0)
# Neutral
# RT @SHIFUJIJAIHIND: क्या आप आज भी चुप रहेंगे? Delhi Kanjhawala Girl Murder Case?
# Sultanpuri Delhi News.
#
# #Sultanpuri #Delhi #Kanjhawala #K…
# Sentiment(polarity=0.0, subjectivity=0.0)
# Neutral
# गृह मंत्री अमित शाह ने दिल्ली में कार से युवती को घसीटे जाने का लिया संज्ञान, पुलिस से रिपोर्ट की तलब
# #MHA… https://t.co/dXhYKOXb8P
# Sentiment(polarity=0.0, subjectivity=0.0)
# Neutral
# @AamAadmiParty @AtishiAAP Ma’am..AAP in full power now..both Delhi State Govt&amp;MCD also..pl leave this petty politic… https://t.co/YqLQFzu6gH
# Sentiment(polarity=0.35, subjectivity=0.55)
# positive
# RT @Indian10000000: 5 arrested in connection with the Delhi woman who was dragged 4 km by car &amp; killed
#
# The victim’s family alleges that sh…
# Sentiment(polarity=-0.1375, subjectivity=0.025)
# Negative
# RT @Shivani_Kash: सनातनी भाई बहन जुड़े और सम्मान से followers पाये।
#
# रीट्वीट करें
# रीट्वीट लिस्ट खोलकर सभी को फोलो करें
# सभी को फॉलोबैक करें…
# Sentiment(polarity=0.0, subjectivity=0.0)
# Neutral
# RT @mangeram89: दिल्ली के कंझावला में हुई घटना से बहुत ही विचलित हूं। हम ये कैसा समाज अपने चारों ओर पनपने दे रहें हैं। सारी संवेदनाएं मिट…
# Sentiment(polarity=0.0, subjectivity=0.0)
# Neutral
# RT @NigarNawab: बेटी जब कई किलोमीटर तक घसीटी जा रही थी तब भी दिल्ली पुलिस सो रही थी
#
# बेटी के मरने के बाद भी सो रही है।
#
# बताया जा रहा है उस…
# Sentiment(polarity=0.0, subjectivity=0.0)
# Neutral
# RT @hatefreeworldX: #Uttarakhand         #Delhi
# BJP ex-MLA’s           BJP
# Son                             worker
#
# Thanks Harish         Wh…
# Sentiment(polarity=0.2, subjectivity=0.2)
# positive
# 14 May, 1962: Dr Rajendra Prasad received a rousing welcome from the citizens of Patna on his arrival from New Delh… https://t.co/6VIakDfdEt
# Sentiment(polarity=0.4681818181818182, subjectivity=0.6772727272727272)
# positive
# RT @Vikastnv: @dtc_union @dtchq_delhi Manniya union ke sabhi adhikariyo ka dil se salam hai, aapke athak- paryas se bahut bada kaam hua hai…
# Sentiment(polarity=0.0, subjectivity=0.0)
# Neutral
# RT @SwatiJaiHind: ना जाँच हुई ना गवाहों से पूछताछ, अपने आप फ़ैसला सुना दिया की सिर्फ़ ऐक्सिडेंट है… क्या छुपाने की कोशिश है?
#
# #Delhi
# Sentiment(polarity=0.0, subjectivity=0.0)
# Neutral
# RT @drunkJournalist: The govts across the country be it Central Govt or Haryana or Gujarat or Delhi or UP etc are working on legalizing ill…
# Sentiment(polarity=0.0, subjectivity=0.25)
# Neutral
# @avgspacelover lots of love for delhi people but some of them make me cringe
# Sentiment(polarity=0.5, subjectivity=0.6)
# positive
# RT @SwatiJaiHind: ना जाँच हुई ना गवाहों से पूछताछ, अपने आप फ़ैसला सुना दिया की सिर्फ़ ऐक्सिडेंट है… क्या छुपाने की कोशिश है?
#
# #Delhi
# Sentiment(polarity=0.0, subjectivity=0.0)
# Neutral
# RT @AamAadmiParty: आख़िर LG और Delhi Police आरोपी BJP नेता को बचाने की कोशिश क्यों कर रहे हैं?
#
# #ShameOnLGSaxena https://t.co/2wUoBjhzN7
# Sentiment(polarity=0.0, subjectivity=0.0)
# Neutral
# RT @ndtv: Watch | AAP Protests Outside Lieutenant Governor's Office After Delhi Car Horror https://t.co/XVRY5GNwLB
# Sentiment(polarity=0.0, subjectivity=0.05)
# Neutral
# RT @AnjaliS73470767: @alpna_07 @Durga_Vahini @rajeevrana1 @kirti_012 @__talasha @Cute_Aditi2 @REAL_ANMOL21 @Shreya__111 @viruvjsang @usha__…
# Sentiment(polarity=0.0, subjectivity=0.0)
# Neutral
# Delhi CM @ArvindKejriwal Flag-offed 50 New DTC Electric Buses in Delhi. This will further strengthen the Delhi's Tr… https://t.co/lV867Iau4e
# Sentiment(polarity=0.06818181818181818, subjectivity=0.4772727272727273)
# positive
# RT @Indian10000000: 5 arrested in connection with the Delhi woman who was dragged 4 km by car &amp; killed
#
# The victim’s family alleges that sh…
# Sentiment(polarity=-0.1375, subjectivity=0.025)
# Negative
# RT @zoo_bear: "दिल्ली ही नहीं पूरे देश को झकझोर देने वाली इस घटना में जो 5 आरोपी हैं, उनमें एक बीजेपी नेता है। बताया जा रहा है कि इस कांड…
# Sentiment(polarity=0.0, subjectivity=0.0)
# Neutral
# RT @tv27cg: दिल्ली के मुख्यमंत्री अरविंद केजरीवाल ने  ट्वीट कर कहा कि कंझावला में हमारी बहन के साथ जो हुआ, वो बेहद शर्मनाक है। मैं उम्मीद क…
# Sentiment(polarity=0.0, subjectivity=0.0)
# Neutral
# RT @ANI: #WATCH | AAP workers gather outside the residence of Delhi LG Vinai Saxena regarding the death of a woman who died after she was d…
# Sentiment(polarity=0.0, subjectivity=0.05)
# Neutral
# RT @ashoswai: On the New Year eve, a 20-year-old girl in India’s capital Delhi, was killed after she was hit by a car and then dragged for…
# Sentiment(polarity=-0.03181818181818183, subjectivity=0.22727272727272727)
# Negative
# @TOKCityOfLights Chicken prices in Delhi is very expensive don't buy from here . ☹️ https://t.co/PK3hsSpKOh
# Sentiment(polarity=-0.625, subjectivity=0.9299999999999999)
# Negative
# Amit Shah seeks detailed report from Delhi Police on Kanjhawla incident, Special Commissioner Shalini Singh given t… https://t.co/RhVaS4YRYZ
# Sentiment(polarity=0.37857142857142856, subjectivity=0.6607142857142857)
# positive
# RT @AamAadmiParty: आख़िर LG और Delhi Police आरोपी BJP नेता को बचाने की कोशिश क्यों कर रहे हैं?
#
# #ShameOnLGSaxena https://t.co/2wUoBjhzN7
# Sentiment(polarity=0.0, subjectivity=0.0)
# Neutral
# RT @AAPOdisha: LG and Delhi Police are trying to protect BJP leaders‼️
#
# 👉Police regd. crime under lighter sections to save the accused
# 👉Eye…
# Sentiment(polarity=0.0, subjectivity=0.0)
# Neutral
# RT @vinodkapri: अविश्वसनीय !!  ये किस दुनिया के लोग हैं ??
#
# “आरोपी युवकों का कहना है कि वह शराब के नशे में थे और कार में तेज आवाज में गाने…
# Sentiment(polarity=0.0, subjectivity=0.0)
# Neutral
# RT @zoo_bear: "दिल्ली ही नहीं पूरे देश को झकझोर देने वाली इस घटना में जो 5 आरोपी हैं, उनमें एक बीजेपी नेता है। बताया जा रहा है कि इस कांड…
# Sentiment(polarity=0.0, subjectivity=0.0)
# Neutral
# RT @NICMeity: Shri Rajesh Gera, Director General, @NICMeity along with MD, NICSI and Senior Officers of NIC called on Hon’ble Union Ministe…
# Sentiment(polarity=0.05000000000000002, subjectivity=0.5)
# positive

# %%
# ploting graphs
plt.xlabel("tags")
plt.ylabel("polarity")
#plt.bar(['pos','neg','neu'],[pos,neg,neu])
plt.pie([pos,neg,neu],labels=['pos','neg','neu'],autopct="%1.1f%%")
plt.show()
